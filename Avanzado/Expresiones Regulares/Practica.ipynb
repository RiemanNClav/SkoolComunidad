# %%
palabras = []
with open('C:/Users/URIEL/Documents/CURSO PYTHON/AUTOMATIZACION TI CON GOOGLE/Expresiones Regulares/Palabras.txt','r', encoding='utf-8') as file:
    for line in file:
        palabras.append(line.strip())

# %%
# EXPRESIONES REGULARES BASICAS 
# contener el string dentro del string que se especifique.
result1 = r'aza'

result = r'aza'

result = r'aza'

##Si no hay coincidencia, el ouput es 'None', significa que no encontro coincidencia. 
##Buscas caracteres al principio:
result2 = r'^oliv'

##Para que la coincidencia no distinga entre mayusculas y minusculas:
result3 = re.search(r'^x.nos','Xenostian', re.IGNORECASE)

## CLASES DE CARACTERES
##se escriben entre corchetes
result4 = r'^[Pp]in'

##podemos definir un rango de caracteres usando un guión:
result5 = r'[a-z]riel'

result6 = r'dat[a-zA-Z0-9]'

## Para buscar cualquier caracter que no sea una letra hata el final.
result7 = r'[^a-zA-Z]*$'

## Buscar cualquier caracter que no sea una letra y un espacio.
result8 = r'[^a-zA-Z ]'

## Que coincida con una palabra o con otra:
result9 = r'Pin|[Mm].l*$'

## Encuentre todos los resultados:
result10 = re.findall(r'cat|dos','I like both dogs and cats.')

## COINCIDENCIAS REPETIDAS
result11 = r'Py.*n'

result12 = r'Py.*n'


result13 = r'Py[a-z]*n'


result14 = r'o+l+'


result15 = r'o+l+'

# CARACTER ESCAPE 
result16 = r'\.com'


result17 = r'\.com'


##\w coincide con letras,números y guiones bajos 
result = r'\w*'

# %%
import re 
dicc = {}
expr_regulares = []
for palabra in palabras:
    
    result = re.search(result9, palabra)
    
    if result != None:
        dicc[palabra] = result[0]
        print('{}---------{}'.format(dicc[palabra],palabra))
# Out:
# m.---------It was not an expensive piece of wood. Far from it. Just a common block of firewood, one of those thick, solid logs that are put on the fire in winter to make cold rooms cozy and warm.
# m.---------If so, the worse for him.
# m.---------He became as wild as a beast and no one could soothe him.
# Pin---------CHAPTER 3 As soon as he gets home, Geppetto fashions the Marionette and calls it Pinocchio. The first pranks of the Marionette
# m.---------Over the fire, there was painted a pot full of something which kept boiling happily away and sending up clouds of what looked like real steam.
# Pin---------I knew a whole family of Pinocchi once—Pinocchio the father, Pinocchia the mother, and Pinocchi the children—and they were all lucky.
# m.---------Fancy his surprise when he noticed that these eyes moved and then stared fixedly at him.
# m.---------No sooner was it finished than it began to laugh and poke fun at him.
# Pin---------“Pinocchio, give me my wig!”
# ...

# %%
result = re.search(r'^A.*[Aa].','ArgeAttino')
print(result[0])

result = re.search(r'A.*a','OOOOOAazajistan')
print(result[0])

result = re.search(r'[Aa].*n$','ooooAazerbaijan')
print(result[0])

result = re.search(r'^A.a$','Australian')
print(result)
# Out:
# ArgeAt
# Aazajista
# Aazerbaijan
# None
